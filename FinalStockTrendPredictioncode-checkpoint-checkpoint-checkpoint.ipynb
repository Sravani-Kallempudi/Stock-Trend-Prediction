# %%
## imorting libraries

import pandas as pd
import numpy as np
import tensorflow as tf
import keras
import sklearn
import math
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
#Reading the amazon stock data from 1 MAY 2007 till date
stock_data = pd.read_csv("AMZN.csv");
stock_data.head()
# Out:
#          Date         Open         High          Low        Close  \
# 0  2018-12-24  1346.000000  1396.030029  1307.000000  1343.959961
# 1  2018-12-26  1368.890015  1473.160034  1363.010010  1470.900024
# 2  2018-12-27  1454.199951  1469.000000  1390.310059  1461.640015
# 3  2018-12-28  1473.349976  1513.469971  1449.000000  1478.020020
# 4  2018-12-31  1510.800049  1520.760010  1487.000000  1501.969971
#
#      Adj Close    Volume
# 0  1343.959961   7220000
# 1  1470.900024  10411800
# 2  1461.640015   9722000
# 3  1478.020020   8829000
# 4  1501.969971   6954500

# %%
# printing the size 
stock_data
# Out:
#            Date         Open         High          Low        Close  \
# 0    2018-12-24  1346.000000  1396.030029  1307.000000  1343.959961
# 1    2018-12-26  1368.890015  1473.160034  1363.010010  1470.900024
# 2    2018-12-27  1454.199951  1469.000000  1390.310059  1461.640015
# 3    2018-12-28  1473.349976  1513.469971  1449.000000  1478.020020
# 4    2018-12-31  1510.800049  1520.760010  1487.000000  1501.969971
# ..          ...          ...          ...          ...          ...
# 247  2019-12-17  1778.010010  1792.000000  1777.390015  1790.660034
# 248  2019-12-18  1795.020020  1798.199951  1782.359985  1784.030029
# 249  2019-12-19  1780.500000  1792.989990  1774.060059  1792.280029
# 250  2019-12-20  1799.619995  1802.969971  1782.449951  1786.500000
# 251  2019-12-23  1788.260010  1793.000000  1784.510010  1793.000000
#
#        Adj Close    Volume
# 0    1343.959961   7220000
# 1    1470.900024  10411800
# 2    1461.640015   9722000
# 3    1478.020020   8829000
# 4    1501.969971   6954500
# ..           ...       ...
# 247  1790.660034   3644400
# 248  1784.030029   3351400
# 249  1792.280029   2652800
# 250  1786.500000   5150800
# 251  1793.000000   2136400
#
# [252 rows x 7 columns]

# %%
# Finding more indictors which are not directly dependent on above features
# Instead they are derived from more one basic features( open, close , etc).

# 1. WillsR

def will(data):
    will = ((data['High'] - data['Close'])/(data['High'] - data['Low'])) * 100
    wills = pd.Series(will , name ="Wills")
    data = data.join(wills)
    return data


# 2. Rocr for 10 days

def roc(df, n = 10):
    """
    
    :param df: pandas.DataFrame
    :param n: 
    :return: pandas.DataFrame
    """
    M = df['Close'].diff(n - 1)
    N = df['Close'].shift(n - 1)
    ROC = pd.Series(M / N, name='ROC_' + str(n))
    df = df.join(ROC)
    return df

# 3. MOM for 10 days

def mom(df, n=10):
    """
    
    :param df: pandas.DataFrame 
    :param n: 
    :return: pandas.DataFrame
    """
    M = pd.Series(df['Close'].diff(n), name='Momentum_' + str(n))
    df = df.join(M)
    return df

# 4. RSI
# price should be dataframe
   
def rsi(df, n=10):
    """Calculate Relative Strength Index(RSI) for given data.
    
    :param df: pandas.DataFrame
    :param n: 
    :return: pandas.DataFrame
    """
    i = 0
    UpI = [0]
    DoI = [0]
    while i + 1 <= df.index[-1]:
        UpMove = df.loc[i + 1, 'High'] - df.loc[i, 'High']
        DoMove = df.loc[i, 'Low'] - df.loc[i + 1, 'Low']
        if UpMove > DoMove and UpMove > 0:
            UpD = UpMove
        else:
            UpD = 0
        UpI.append(UpD)
        if DoMove > UpMove and DoMove > 0:
            DoD = DoMove
        else:
            DoD = 0
        DoI.append(DoD)
        i = i + 1
    UpI = pd.Series(UpI)
    DoI = pd.Series(DoI)
    PosDI = pd.Series(UpI.ewm(span=n, min_periods=n).mean())
    NegDI = pd.Series(DoI.ewm(span=n, min_periods=n).mean())
    RSI = pd.Series(PosDI / (PosDI + NegDI), name='RSI_' + str(n))
    df = df.join(RSI)
    return df


# 5. cci

def cci(data, ndays = 10): 
    TP = (data['High'] + data['Low'] + data['Close']) / 3 
    CCI = pd.Series((TP - pd.Series(TP).rolling(window=ndays).mean()) / (0.015 * pd.Series(TP).rolling(window=ndays).std()), name = 'CCI') 
    data = data.join(CCI) 
    return data


# 6 . adx

def adx(df, n = 10 , n_ADX = 10):
    """Calculate the Average Directional Movement Index for given data.
    
    :param df: pandas.DataFrame
    :param n: 
    :param n_ADX: 
    :return: pandas.DataFrame
    """
    i = 0
    UpI = []
    DoI = []
    while i + 1 <= df.index[-1]:
        UpMove = df.loc[i + 1, 'High'] - df.loc[i, 'High']
        DoMove = df.loc[i, 'Low'] - df.loc[i + 1, 'Low']
        if UpMove > DoMove and UpMove > 0:
            UpD = UpMove
        else:
            UpD = 0
        UpI.append(UpD)
        if DoMove > UpMove and DoMove > 0:
            DoD = DoMove
        else:
            DoD = 0
        DoI.append(DoD)
        i = i + 1
    i = 0
    TR_l = [0]
    while i < df.index[-1]:
        TR = max(df.loc[i + 1, 'High'], df.loc[i, 'Close']) - min(df.loc[i + 1, 'Low'], df.loc[i, 'Close'])
        TR_l.append(TR)
        i = i + 1
    TR_s = pd.Series(TR_l)
    ATR = pd.Series(TR_s.ewm(span=n, min_periods=n).mean())
    UpI = pd.Series(UpI)
    DoI = pd.Series(DoI)
    PosDI = pd.Series(UpI.ewm(span=n, min_periods=n).mean() / ATR)
    NegDI = pd.Series(DoI.ewm(span=n, min_periods=n).mean() / ATR)
    ADX = pd.Series((abs(PosDI - NegDI) / (PosDI + NegDI)).ewm(span=n_ADX, min_periods=n_ADX).mean(),
                    name='Adx')
    df = df.join(ADX)
    return df


# 7. trix

def trix(df, n = 10):
    """Calculate TRIX for given data.
    
    :param df: pandas.DataFrame
    :param n: 
    :return: pandas.DataFrame
    """
    EX1 = df['Close'].ewm(span=n, min_periods=n).mean()
    EX2 = EX1.ewm(span=n, min_periods=n).mean()
    EX3 = EX2.ewm(span=n, min_periods=n).mean()
    i = 0
    ROC_l = [np.nan]
    while i + 1 <= df.index[-1]:
        ROC = (EX3[i + 1] - EX3[i]) / EX3[i]
        ROC_l.append(ROC)
        i = i + 1
    Trix = pd.Series(ROC_l, name='Trix')
    df = df.join(Trix)
    return df

# 8. macd

def macd(df, n_fast = 2 , n_slow = 3):
    """Calculate MACD, MACD Signal and MACD difference
    
    :param df: pandas.DataFrame
    :param n_fast: 
    :param n_slow: 
    :return: pandas.DataFrame
    """
    EMAfast = pd.Series(df['Close'].ewm(span=n_fast, min_periods=n_slow).mean())
    EMAslow = pd.Series(df['Close'].ewm(span=n_slow, min_periods=n_slow).mean())
    MACD = pd.Series(EMAfast - EMAslow, name='MACD_' + str(n_fast) + '_' + str(n_slow))
    MACDsign = pd.Series(MACD.ewm(span=9, min_periods=9).mean(), name='MACDsign_' + str(n_fast) + '_' + str(n_slow))
    MACDdiff = pd.Series(MACD - MACDsign, name='MACDdiff_' + str(n_fast) + '_' + str(n_slow))
    df = df.join(MACD)
    df = df.join(MACDsign)
    df = df.join(MACDdiff)
    return df


# 9 . obv

def obv(df, n = 10):
    """Calculate On-Balance Volume for given data.
    
    :param df: pandas.DataFrame
    :param n: 
    :return: pandas.DataFrame
    """
    i = 0
    OBV = [0]
    while i < df.index[-1]:
        if df.loc[i + 1, 'Close'] - df.loc[i, 'Close'] > 0:
            OBV.append(df.loc[i + 1, 'Volume'])
        if df.loc[i + 1, 'Close'] - df.loc[i, 'Close'] == 0:
            OBV.append(0)
        if df.loc[i + 1, 'Close'] - df.loc[i, 'Close'] < 0:
            OBV.append(-df.loc[i + 1, 'Volume'])
        i = i + 1
    OBV = pd.Series(OBV)
    OBV_ma = pd.Series(OBV.rolling(n, min_periods=n).mean(), name='Obv')
    df = df.join(OBV_ma)
    return df

# 10 . atr

def atr(df, n = 10):
    """
    
    :param df: pandas.DataFrame
    :param n: 
    :return: pandas.DataFrame
    """
    i = 0
    TR_l = [0]
    while i < df.index[-1]:
        TR = max(df.loc[i + 1, 'High'], df.loc[i, 'Close']) - min(df.loc[i + 1, 'Low'], df.loc[i, 'Close'])
        TR_l.append(TR)
        i = i + 1
    TR_s = pd.Series(TR_l)
    ATR = pd.Series(TR_s.ewm(span=n, min_periods=n).mean(), name='ATR_' + str(n))
    df = df.join(ATR)
    return df


# 11 . mfi

def mfi(df, n=10):
    """Calculate Money Flow Index and Ratio for given data.
    
    :param df: pandas.DataFrame
    :param n: 
    :return: pandas.DataFrame
    """
    PP = (df['High'] + df['Low'] + df['Close']) / 3
    i = 0
    PosMF = [0]
    while i < df.index[-1]:
        if PP[i + 1] > PP[i]:
            PosMF.append(PP[i + 1] * df.loc[i + 1, 'Volume'])
        else:
            PosMF.append(0)
        i = i + 1
    PosMF = pd.Series(PosMF)
    TotMF = PP * df['Volume']
    MFR = pd.Series(PosMF / TotMF)
    MFI = pd.Series(MFR.rolling(n, min_periods=n).mean(), name='MFI')
    df = df.join(MFI)
    return df

# %%
# applying the original stock_data to the above funtions to result in additional features(columns)
stock_data = mfi(atr(obv(macd(trix(adx(cci(rsi(mom(roc(stock_data))))))))))
stock_data
# Out:
#            Date         Open         High          Low        Close  \
# 0    2018-12-24  1346.000000  1396.030029  1307.000000  1343.959961
# 1    2018-12-26  1368.890015  1473.160034  1363.010010  1470.900024
# 2    2018-12-27  1454.199951  1469.000000  1390.310059  1461.640015
# 3    2018-12-28  1473.349976  1513.469971  1449.000000  1478.020020
# 4    2018-12-31  1510.800049  1520.760010  1487.000000  1501.969971
# ..          ...          ...          ...          ...          ...
# 247  2019-12-17  1778.010010  1792.000000  1777.390015  1790.660034
# 248  2019-12-18  1795.020020  1798.199951  1782.359985  1784.030029
# 249  2019-12-19  1780.500000  1792.989990  1774.060059  1792.280029
# 250  2019-12-20  1799.619995  1802.969971  1782.449951  1786.500000
# 251  2019-12-23  1788.260010  1793.000000  1784.510010  1793.000000
#
#        Adj Close    Volume    ROC_10  Momentum_10    RSI_10         CCI  \
# 0    1343.959961   7220000       NaN          NaN       NaN         NaN
# 1    1470.900024  10411800       NaN          NaN       NaN         NaN
# 2    1461.640015   9722000       NaN          NaN       NaN         NaN
# 3    1478.020020   8829000       NaN          NaN       NaN         NaN
# 4    1501.969971   6954500       NaN          NaN       NaN         NaN
# ..           ...       ...       ...          ...       ...         ...
# 247  1790.660034   3644400  0.017022    20.700073  0.745652  141.340509
# 248  1784.030029   3351400  0.025022    23.340088  0.773801  116.392346
# 249  1792.280029   2652800  0.023225    51.800049  0.655164   86.122383
# 250  1786.500000   5150800  0.021143    34.900024  0.718574   81.302302
# 251  1793.000000   2136400  0.030928    43.489990  0.718574   64.952522
#
#           Adx      Trix  MACD_2_3  MACDsign_2_3  MACDdiff_2_3        Obv  \
# 0         NaN       NaN       NaN           NaN           NaN        NaN
# 1         NaN       NaN       NaN           NaN           NaN        NaN
# 2         NaN       NaN  7.250333           NaN           NaN        NaN
# 3         NaN       NaN  6.683669           NaN           NaN        NaN
# 4         NaN       NaN  8.065958           NaN           NaN        NaN
# ..        ...       ...       ...           ...           ...        ...
# 247  0.295501 -0.000310  5.439899      1.326854      4.113045   739520.0
# 248  0.298196 -0.000138  2.991498      1.659782      1.331716   671390.0
# 249  0.323461  0.000062  2.961265      1.920079      1.041186  1219050.0
# 250  0.344131  0.000240  1.005800      1.737223     -0.731423   392230.0
# 251  0.344131  0.000410  1.427956      1.675370     -0.247414   850150.0
#
#         ATR_10  MFI
# 0          NaN  NaN
# 1          NaN  NaN
# 2          NaN  NaN
# 3          NaN  NaN
# 4          NaN  NaN
# ..         ...  ...
# 247  19.127379  0.8
# 248  18.529667  0.8
# 249  18.602442  0.8
# 250  18.951093  0.8
# 251  17.049074  0.7
#
# [252 rows x 19 columns]

# %%
# preparing target

def target_prep(df , n =10):
  df = df[::-1]   # flipping the data frame so that current date comes in the top
  target = (df['Close'] - df['Close'].shift(-10)) > 0
  target = target * 1
  targ = pd.Series(target, name='target')
  df = df.join(targ)
  return df

# %%
# Adding target to the data frame and deleting last 30 rows to tackle NAN's
stock_data_with_target = target_prep(stock_data)
stock_data_with_target.drop(stock_data_with_target.tail(30).index,inplace=True)

# %%
stock_data_with_target.shape
# Out:
# (222, 20)

# %%
stock_data_with_target.head()
# Out:
#            Date         Open         High          Low        Close  \
# 251  2019-12-23  1788.260010  1793.000000  1784.510010  1793.000000
# 250  2019-12-20  1799.619995  1802.969971  1782.449951  1786.500000
# 249  2019-12-19  1780.500000  1792.989990  1774.060059  1792.280029
# 248  2019-12-18  1795.020020  1798.199951  1782.359985  1784.030029
# 247  2019-12-17  1778.010010  1792.000000  1777.390015  1790.660034
#
#        Adj Close   Volume    ROC_10  Momentum_10    RSI_10         CCI  \
# 251  1793.000000  2136400  0.030928    43.489990  0.718574   64.952522
# 250  1786.500000  5150800  0.021143    34.900024  0.718574   81.302302
# 249  1792.280029  2652800  0.023225    51.800049  0.655164   86.122383
# 248  1784.030029  3351400  0.025022    23.340088  0.773801  116.392346
# 247  1790.660034  3644400  0.017022    20.700073  0.745652  141.340509
#
#           Adx      Trix  MACD_2_3  MACDsign_2_3  MACDdiff_2_3        Obv  \
# 251  0.344131  0.000410  1.427956      1.675370     -0.247414   850150.0
# 250  0.344131  0.000240  1.005800      1.737223     -0.731423   392230.0
# 249  0.323461  0.000062  2.961265      1.920079      1.041186  1219050.0
# 248  0.298196 -0.000138  2.991498      1.659782      1.331716   671390.0
# 247  0.295501 -0.000310  5.439899      1.326854      4.113045   739520.0
#
#         ATR_10  MFI  target
# 251  17.049074  0.7       1
# 250  18.951093  0.8       1
# 249  18.602442  0.8       1
# 248  18.529667  0.8       1
# 247  19.127379  0.8       1

# %%
# preparing feature_set and target_set from the complete data

feature_set = stock_data_with_target.drop(['target'], axis = 1)
target_set = stock_data_with_target['target']

# %%
feature_set.head()
# Out:
#            Date         Open         High          Low        Close  \
# 251  2019-12-23  1788.260010  1793.000000  1784.510010  1793.000000
# 250  2019-12-20  1799.619995  1802.969971  1782.449951  1786.500000
# 249  2019-12-19  1780.500000  1792.989990  1774.060059  1792.280029
# 248  2019-12-18  1795.020020  1798.199951  1782.359985  1784.030029
# 247  2019-12-17  1778.010010  1792.000000  1777.390015  1790.660034
#
#        Adj Close   Volume    ROC_10  Momentum_10    RSI_10         CCI  \
# 251  1793.000000  2136400  0.030928    43.489990  0.718574   64.952522
# 250  1786.500000  5150800  0.021143    34.900024  0.718574   81.302302
# 249  1792.280029  2652800  0.023225    51.800049  0.655164   86.122383
# 248  1784.030029  3351400  0.025022    23.340088  0.773801  116.392346
# 247  1790.660034  3644400  0.017022    20.700073  0.745652  141.340509
#
#           Adx      Trix  MACD_2_3  MACDsign_2_3  MACDdiff_2_3        Obv  \
# 251  0.344131  0.000410  1.427956      1.675370     -0.247414   850150.0
# 250  0.344131  0.000240  1.005800      1.737223     -0.731423   392230.0
# 249  0.323461  0.000062  2.961265      1.920079      1.041186  1219050.0
# 248  0.298196 -0.000138  2.991498      1.659782      1.331716   671390.0
# 247  0.295501 -0.000310  5.439899      1.326854      4.113045   739520.0
#
#         ATR_10  MFI
# 251  17.049074  0.7
# 250  18.951093  0.8
# 249  18.602442  0.8
# 248  18.529667  0.8
# 247  19.127379  0.8

# %%
target_set.head()
# Out:
# 251    1
# 250    1
# 249    1
# 248    1
# 247    1
# Name: target, dtype: int32

# %%
X = feature_set
y = target_set


# plot from beginning of the period to end of the period
plt.plot(X['Date'] , X['Close'] , color = 'green' )
plt.title('Stock Trend from start to end')
plt.xlabel('Date')
plt.ylabel('Close')
plt.legend()
plt.show()

# plot of last ten days
plt.plot(X.head(10)['Date'] , X.head(10)['Close'] , color = 'blue' )
plt.xticks(rotation=90)
plt.title('Stock Trend for first ten days')
plt.xlabel('Date')
plt.ylabel('Close')
plt.legend()
plt.show()


# plot of first ten days
plt.plot(X.tail(10)['Date'] , X.tail(10)['Close'] , color = 'blue' )
plt.xticks(rotation=90)
plt.title('Stock Trend for last ten days')
plt.xlabel('Date')
plt.ylabel('Close')
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %%
# corelation heatmap
# Light color indicates high co-relation

import seaborn as sns

corelations = feature_set.corr()
fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(corelations, vmax=1.0, center=0, fmt='.2f', square=True, linewidths=.5, annot=True, cbar_kws={"shrink": .70})
plt.show();

# %%
# Dropping Date, Close, Adj Close as they where related to target
feature_set = stock_data_with_target.drop(['Date','Close', 'Adj Close','target'], axis = 1)
# fill na values with the mean of particular column
feature_set.fillna(feature_set.mean() , inplace = True)

# %%
#Normalization

from sklearn import preprocessing

min_max_scaler = preprocessing.MinMaxScaler()
feature_set_normalized = min_max_scaler.fit_transform(feature_set)

# %%
#split the data into train and testing in 75% and 25% respectively

def non_shuffling_train_test_split(features, target, train_size=0.75):
  train_number = math.ceil(features.shape[0] * (train_size))
  test_number = features.shape[0] - train_number

  X_train = features[test_number:]
  X_test = features[0:test_number]

  y_train = target[test_number:]
  y_test = target[0:test_number]
  return X_train, X_test, y_train, y_test

X_train , X_val, y_train, y_val = non_shuffling_train_test_split(feature_set_normalized, target_set)

# %%
print("training size")
print(y_train.size)
print("testing size")
print(y_val.size)
# Out:
# training size
# 167
# testing size
# 55

# %%
# Machine Learning part

# %%
#Logistic Regression

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

clf = LogisticRegression(penalty='l2' ,random_state=2, solver='lbfgs', max_iter=40).fit(X_train, y_train)
pred = clf.predict(X_val)
accuracy_score(y_val, pred)
# Out:
# 0.9272727272727272

# %%
from sklearn.svm import SVC

clf = SVC(gamma='auto', max_iter=350 )
clf.fit(X_train, y_train)
pred = clf.predict(X_val)
accuracy_score(y_val, pred)
# Out:
# 0.9090909090909091

# %%
# Neural Networks

from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
# model 

model = Sequential()
model.add(Dense(200, input_dim = X_train.shape[1] , activation="relu"))
model.add(Dense(25, activation="relu"))
model.add(Dense(1, activation="linear"))

opt = Adam()

model.compile(loss = 'mse' , optimizer = opt , metrics = ['accuracy'])

# %%
# study these at
# https://stackoverflow.com/questions/43906048/keras-early-stopping

callbacks = [
             EarlyStopping(monitor='val_acc', patience=20, verbose=2),
             ModelCheckpoint('C:\/stock_trend.h5', monitor='val_acc', save_best_only=True, verbose=0)
            ]

# %%
batch_size = 8
n_epochs = 5000

# %%
model.fit(X_train , y_train , batch_size=batch_size , epochs = n_epochs , validation_split=0.2,     
             verbose=2,
             validation_data=(X_val, y_val),
             callbacks=callbacks)
